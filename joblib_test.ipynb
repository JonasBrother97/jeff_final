# %%
from joblib import load

knn = load('joblib/knn.joblib')
dtc = load('joblib/dtc.joblib')
X_test = load('joblib/X_test.joblib')
y_test = load('joblib/y_test.joblib')

# %%
knn.score(X_test, y_test)
# Out:
# 0.7076023391812866
